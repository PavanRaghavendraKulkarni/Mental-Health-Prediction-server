# %%
# !pip install openai
# !pip install transformers
# Out:
# ...
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# WARNING: You are using pip version 20.1.1; however, version 22.1.2 is available.
# You should consider upgrading via the 'e:\python.exe -m pip install --upgrade pip' command.
# ...
# ^C

# %%
import openai

# %%
import openai
openai.api_key = "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"
openai.Engine.list()
# Out:
# <OpenAIObject list at 0x23decdd4cc0> JSON: {
#   "data": [
#     {
#       "created": null,
#       "id": "davinci-instruct-beta",
#       "object": "engine",
#       "owner": "openai",
#       "permissions": null,
#       "ready": true
#     },
#     {
#       "created": null,
#       "id": "ada",
#       "object": "engine",
#       "owner": "openai",
#       "permissions": null,
#       "ready": true
#     },
#     {
#       "created": null,
#       "id": "ada-search-document",
#       "object": "engine",
#       "owner": "openai-dev",
#       "permissions": null,
#       "ready": true
#     },
#     {
#       "created": null,
#       "id": "davinci",
#       "object": "engine",
#       "owner": "openai",
#       "permissions": null,
#       "ready": true
#     },
#     {
#       "created": null,
#       "id": "text-babbage-001",
#       "object": "engine",
#       "owner": "openai",
#       "permissions": null,
#       "ready": true
#     },
#     {
#       "created": null,
# ...

# %%
openai.File.create(file=open("test.jsonl"), purpose="classifications")
#Bhai wo id copy kar le
# Out:
# <File file id=file-ipYxEBf8HDrgCPl2eLkxX7Al at 0x23ddee3a130> JSON: {
#   "bytes": 374033,
#   "created_at": 1654755100,
#   "filename": "file",
#   "id": "file-ipYxEBf8HDrgCPl2eLkxX7Al",
#   "object": "file",
#   "purpose": "classifications",
#   "status": "uploaded",
#   "status_details": null
# }

# %%
from transformers import GPT2TokenizerFast

# Load the tokenizer.
tokenizer = GPT2TokenizerFast.from_pretrained("gpt2")

# Make sure the labels are formatted correctly.
labels = ['depression','ptsd','schizophrenia','adhd','bipolar','autism','bpd','anxiety']
#labels = [label.strip().lower().capitalize() for label in labels]

# Encode the labels with extra white space prepended.
labels_tokens = {label: tokenizer.encode(" " + label) for label in labels}
print(labels_tokens)
# Out:
# Downloading: 100%|██████████| 0.99M/0.99M [00:05<00:00, 204kB/s]
# Downloading: 100%|██████████| 446k/446k [00:02<00:00, 168kB/s]
# Downloading: 100%|██████████| 1.29M/1.29M [00:06<00:00, 208kB/s]
# Downloading: 100%|██████████| 665/665 [00:00<00:00, 83.2kB/s]
# {'depression': [8862], 'ptsd': [43344, 67], 'schizophrenia': [22794], 'adhd': [512, 31298], 'bipolar': [31170], 'autism': [15998], 'bpd': [275, 30094], 'anxiety': [9751]}

# %%
import openai
# Query the /classifications endpoint.
result = openai.Classification.create(
    #wo copy kiya huwa id niche paste kar de
    file="file-ipYxEBf8HDrgCPl2eLkxX7Al",
    query="i am feeling like killing myself",
    search_model="ada",
    model="curie",
    max_examples=8,
    labels=labels,
    logprobs=9,  # Here we set it to be len(labels) + 1, but it can be larger.
    expand=["completion"]
)

# %%
print(result.label)
# Out:
# Depression
